# %% [markdown]
# ### Importing the Libraries

# %%
import os, cv2, random
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Model

# %% [markdown]
# ### Reading the Training Dataset

# %%
directory = "./Training Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_train = []
y_train = []

for image, label in dataset:
    x_train.append(image)
    y_train.append(label)

x_train = np.array(x_train)
y_train = np.array(y_train)

# %% [markdown]
# ### Reading the Validation Dataset

# %%
directory = "./Validation Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_val = []
y_val = []

for image, label in dataset:
    x_val.append(image)
    y_val.append(label)

x_val = np.array(x_val)
y_val = np.array(y_val)

# %% [markdown]
# ### Reading the Test Dataset

# %%
directory = "./Test Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_test = []
y_test = []

for image, label in dataset:
    x_test.append(image)
    y_test.append(label)

x_test = np.array(x_test)
y_test = np.array(y_test)

# %% [markdown]
# ### Function for Generating Label

# %%
def get_label(label):
    if not label:
        return "Grape"
    return "Raisin"

# %% [markdown]
# ### Displaying some samples

# %%
plt.figure(figsize = (13, 13))
for k in range(1, 10):
    plt.subplot(3, 3, k)
    plt.imshow(cv2.cvtColor(x_train[k], cv2.COLOR_BGR2RGB))
    plt.title(get_label(y_train[k]))
    plt.axis("off")

plt.suptitle("Sample Images from Dataset")
plt.show()

# %% [markdown]
# ### Showing the Train, Validation & Test Set Shape

# %%
print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_val.shape, y_val.shape)
print("Test set:", x_test.shape, y_test.shape)
# Out:
# Training set: (1070, 32, 32, 3) (1070,)
# Validation set: (260, 32, 32, 3) (260,)
# Test set: (420, 32, 32, 3) (420,)

# %% [markdown]
# ### Building the Model

# %%
inputs = Input(shape = (32, 32, 3))

x = Flatten()(inputs)

x = Dense(128, activation = "relu")(x)
x = Dense(256, activation = "relu")(x)
x = Dense(512, activation = "relu")(x)
x = Dense(256, activation = "relu")(x)
x = Dense(128, activation = "relu")(x)

outputs = Dense(1, activation = "sigmoid")(x)

model = Model(inputs = inputs, outputs = outputs)

model.compile(optimizer = Adam(0.00001), loss = "binary_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │       393,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 722,305 (2.76 MB)
#  Trainable params: 722,305 (2.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs = 50, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4928 - loss: 28.2294 - val_accuracy: 0.5654 - val_loss: 2.2995
# Epoch 2/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6476 - loss: 1.6892 - val_accuracy: 0.6692 - val_loss: 1.1049
# Epoch 3/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7462 - loss: 0.9315 - val_accuracy: 0.7346 - val_loss: 0.8477
# Epoch 4/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8049 - loss: 0.6371 - val_accuracy: 0.7962 - val_loss: 0.6663
# Epoch 5/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8448 - loss: 0.4291 - val_accuracy: 0.8192 - val_loss: 0.6770
# Epoch 6/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8624 - loss: 0.4580 - val_accuracy: 0.8115 - val_loss: 0.5409
# Epoch 7/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8869 - loss: 0.2884 - val_accuracy: 0.7923 - val_loss: 0.5445
# Epoch 8/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8873 - loss: 0.3218 - val_accuracy: 0.8385 - val_loss: 0.4706
# Epoch 9/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9107 - loss: 0.2309 - val_accuracy: 0.8462 - val_loss: 0.4508
# Epoch 10/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9242 - loss: 0.2090 - val_accuracy: 0.8615 - val_loss: 0.4201
# Epoch 11/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9399 - loss: 0.1616 - val_accuracy: 0.8500 - val_loss: 0.3985
# Epoch 12/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9261 - loss: 0.1597 - val_accuracy: 0.8692 - val_loss: 0.3733
# Epoch 13/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9587 - loss: 0.1149 - val_accuracy: 0.8654 - val_loss: 0.3670
# Epoch 14/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9477 - loss: 0.1349 - val_accuracy: 0.8808 - val_loss: 0.3583
# Epoch 15/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9665 - loss: 0.0999 - val_accuracy: 0.8462 - val_loss: 0.4666
# Epoch 16/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9342 - loss: 0.1541 - val_accuracy: 0.8846 - val_loss: 0.3218
# Epoch 17/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9700 - loss: 0.0833 - val_accuracy: 0.8808 - val_loss: 0.3677
# Epoch 18/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9672 - loss: 0.0947 - val_accuracy: 0.8846 - val_loss: 0.3335
# Epoch 19/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9746 - loss: 0.0681 - val_accuracy: 0.8769 - val_loss: 0.3577
# Epoch 20/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9746 - loss: 0.0865 - val_accuracy: 0.9038 - val_loss: 0.3217
# Epoch 21/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9715 - loss: 0.0654 - val_accuracy: 0.8731 - val_loss: 0.3389
# Epoch 22/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9903 - loss: 0.0615 - val_accuracy: 0.8962 - val_loss: 0.2898
# Epoch 23/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9799 - loss: 0.0707 - val_accuracy: 0.8808 - val_loss: 0.3490
# Epoch 24/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9758 - loss: 0.0667 - val_accuracy: 0.8923 - val_loss: 0.3082
# Epoch 25/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9900 - loss: 0.0461 - val_accuracy: 0.9154 - val_loss: 0.2918
# Epoch 26/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9838 - loss: 0.0535 - val_accuracy: 0.9115 - val_loss: 0.2720
# Epoch 27/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9946 - loss: 0.0357 - val_accuracy: 0.8808 - val_loss: 0.3372
# Epoch 28/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9836 - loss: 0.0600 - val_accuracy: 0.9154 - val_loss: 0.2692
# Epoch 29/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9961 - loss: 0.0356 - val_accuracy: 0.9077 - val_loss: 0.2715
# Epoch 30/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9956 - loss: 0.0385 - val_accuracy: 0.9115 - val_loss: 0.2613
# Epoch 31/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - loss: 0.0344 - val_accuracy: 0.9154 - val_loss: 0.2724
# Epoch 32/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9931 - loss: 0.0351 - val_accuracy: 0.9000 - val_loss: 0.2944
# Epoch 33/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9926 - loss: 0.0331 - val_accuracy: 0.9038 - val_loss: 0.2660
# Epoch 34/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9954 - loss: 0.0258 - val_accuracy: 0.9077 - val_loss: 0.2723
# Epoch 35/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.0271 - val_accuracy: 0.9115 - val_loss: 0.2904
# Epoch 36/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0357 - val_accuracy: 0.8692 - val_loss: 0.3844
# Epoch 37/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 0.0472 - val_accuracy: 0.9154 - val_loss: 0.2427
# Epoch 38/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - loss: 0.0235 - val_accuracy: 0.9192 - val_loss: 0.2477
# Epoch 39/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9979 - loss: 0.0196 - val_accuracy: 0.9192 - val_loss: 0.2471
# Epoch 40/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - loss: 0.0231 - val_accuracy: 0.9077 - val_loss: 0.2777
# Epoch 41/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9966 - loss: 0.0224 - val_accuracy: 0.9231 - val_loss: 0.2495
# Epoch 42/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9986 - loss: 0.0186 - val_accuracy: 0.9154 - val_loss: 0.2440
# Epoch 43/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.0201 - val_accuracy: 0.9115 - val_loss: 0.2524
# Epoch 44/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0135 - val_accuracy: 0.9231 - val_loss: 0.2415
# Epoch 45/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.9154 - val_loss: 0.2465
# Epoch 46/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0135 - val_accuracy: 0.9308 - val_loss: 0.2357
# Epoch 47/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.9231 - val_loss: 0.2392
# Epoch 48/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9192 - val_loss: 0.2325
# Epoch 49/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.9231 - val_loss: 0.2400
# Epoch 50/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.9231 - val_loss: 0.2341

# %% [markdown]
# ### Plotting The Accuracy & Loss Graph

# %%
plt.figure(figsize = (17, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label = "Accuracy")
plt.plot(history.history["val_accuracy"], label = "Validation Accuracy")
plt.title("Training & Validation Accuracy", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel("Epochs", fontsize = 16)
plt.ylabel("Accuracy", fontsize = 16)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label = "Loss")
plt.plot(history.history["val_loss"], label = "Validation Loss")
plt.title("Training & Validation Loss", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel("Epochs", fontsize = 16)
plt.ylabel("Loss", fontsize = 16)
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluating the Model on Test Set

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f"Test Accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7221 - loss: 1.5408
# Test Accuracy: 71.67%
