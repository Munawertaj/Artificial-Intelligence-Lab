# %% [markdown]
# ### Importing the Libraries

# %%
import cv2
import random
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Activation, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Reading the Dataset

# %%
directory = "./Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name, 0)
        dataset.append([image, label])

random.shuffle(dataset)

# %% [markdown]
# ### Creating x & y

# %%
x = []
y = []

for image, label in dataset:
    x.append(image)
    y.append(label)

x = np.array(x)
y = np.array(y)

# %% [markdown]
# ### Function for Generating Label

# %%
def get_label(label):
    if not label:
        return "Grape"
    return "Raisin"

# %% [markdown]
# ### Displaying some samples

# %%
plt.figure(figsize = (13, 13))
for k in range(1, 10):
    plt.subplot(3, 3, k)
    plt.imshow(cv2.cvtColor(x[k], cv2.COLOR_BGR2RGB))
    plt.title(get_label(y[k]))
    plt.axis("off")

plt.suptitle("Sample Images from Dataset")
plt.show()

# %% [markdown]
# ### Splitting the Dataset into Training & Test Set

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 12)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 12)

print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_val.shape, y_val.shape)
print("Test set:", x_test.shape, y_test.shape)
# Out:
# Training set: (544, 32, 32) (544,)
# Validation set: (136, 32, 32) (136,)
# Test set: (170, 32, 32) (170,)

# %% [markdown]
# ### Building the Model

# %%
inputs = Input(shape = (32, 32, 1))

x = Conv2D(32, (3, 3), activation = "relu")(inputs)
x = Conv2D(32, (3, 3), activation = "relu")(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation = "relu")(x)
x = Conv2D(64, (3, 3), activation = "relu")(x)
x = Conv2D(64, (3, 3), activation = "relu")(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(32, (3, 3), activation = "relu")(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)

x = Dense(512, activation = "relu")(x)
x = Dense(256, activation = "relu")(x)
x = Dense(128, activation = "relu")(x)

outputs = Dense(1, activation = "sigmoid")(x)

model = Model(inputs = inputs, outputs = outputs)

model.compile(optimizer = Adam(0.0001), loss = "binary_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 32, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 30, 30, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 28, 28, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 10, 10, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 2, 2, 32)       │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 1, 1, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 512)            │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 301,633 (1.15 MB)
#  Trainable params: 301,633 (1.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs = 30, validation_data = (x_val, y_val))
# Out:
# Epoch 1/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.5358 - loss: 0.7052 - val_accuracy: 0.5882 - val_loss: 0.6640
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6447 - loss: 0.6421 - val_accuracy: 0.6176 - val_loss: 0.6408
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6890 - loss: 0.5767 - val_accuracy: 0.7426 - val_loss: 0.5515
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7266 - loss: 0.5527 - val_accuracy: 0.7206 - val_loss: 0.5583
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7579 - loss: 0.4883 - val_accuracy: 0.7426 - val_loss: 0.5122
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7662 - loss: 0.4607 - val_accuracy: 0.8162 - val_loss: 0.4236
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8579 - loss: 0.3781 - val_accuracy: 0.8676 - val_loss: 0.3862
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7854 - loss: 0.4064 - val_accuracy: 0.4853 - val_loss: 0.7522
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7259 - loss: 0.5003 - val_accuracy: 0.7868 - val_loss: 0.4944
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8524 - loss: 0.3484 - val_accuracy: 0.5735 - val_loss: 0.6646
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7749 - loss: 0.4330 - val_accuracy: 0.8824 - val_loss: 0.3826
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8669 - loss: 0.2852 - val_accuracy: 0.8971 - val_loss: 0.3166
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9066 - loss: 0.2521 - val_accuracy: 0.8971 - val_loss: 0.3402
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9151 - loss: 0.2304 - val_accuracy: 0.8382 - val_loss: 0.4317
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9218 - loss: 0.2222 - val_accuracy: 0.9265 - val_loss: 0.2726
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9696 - loss: 0.1609 - val_accuracy: 0.9338 - val_loss: 0.2784
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9478 - loss: 0.1622 - val_accuracy: 0.9265 - val_loss: 0.2824
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9638 - loss: 0.1294 - val_accuracy: 0.9485 - val_loss: 0.2592
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9673 - loss: 0.1220 - val_accuracy: 0.9191 - val_loss: 0.3175
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9743 - loss: 0.1001 - val_accuracy: 0.9412 - val_loss: 0.2610
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9767 - loss: 0.0829 - val_accuracy: 0.9412 - val_loss: 0.2755
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9601 - loss: 0.1252 - val_accuracy: 0.9338 - val_loss: 0.2635
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9780 - loss: 0.0848 - val_accuracy: 0.9191 - val_loss: 0.2999
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9735 - loss: 0.0920 - val_accuracy: 0.9191 - val_loss: 0.2769
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9685 - loss: 0.0926 - val_accuracy: 0.9338 - val_loss: 0.2885
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9806 - loss: 0.0829 - val_accuracy: 0.9118 - val_loss: 0.3496
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9718 - loss: 0.0623 - val_accuracy: 0.9338 - val_loss: 0.2641
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9774 - loss: 0.0655 - val_accuracy: 0.9559 - val_loss: 0.2696
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9863 - loss: 0.0597 - val_accuracy: 0.9412 - val_loss: 0.2739
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9961 - loss: 0.0370 - val_accuracy: 0.9265 - val_loss: 0.2799

# %% [markdown]
# ### Plotting The Accuracy & Loss Graph

# %%
plt.figure(figsize = (17, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label = "Accuracy")
plt.plot(history.history["val_accuracy"], label = "Validation Accuracy")
plt.title("Training & Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label = "Loss")
plt.plot(history.history["val_loss"], label = "Validation Loss")
plt.title("Training & Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluating the Model on Test Set

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f"Test Accuracy: {round(test_accuracy * 100, 2)}%")
print(f"Test Loss: {round(test_loss * 100, 2)}%")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8676 - loss: 0.3102
# Test Accuracy: 87.65%
# Test Loss: 37.77%
