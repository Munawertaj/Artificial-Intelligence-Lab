# %% [markdown]
# ### Importing the Libraries

# %%
import cv2
import random
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Activation, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Reading the Dataset

# %%
directory = "./Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name,0)
        dataset.append([image, label])

random.shuffle(dataset)

# %% [markdown]
# ### Creating x & y

# %%
x = []
y = []

for image, label in dataset:
    x.append(image)
    y.append(label)

x = np.array(x)
y = np.array(y)

# %% [markdown]
# ### Function for Generating Label

# %%
def get_label(label):
    if not label:
        return "Grape"
    return "Raisin"

# %% [markdown]
# ### Displaying some samples

# %%
plt.figure(figsize = (13, 13))
for k in range(1, 10):
    plt.subplot(3, 3, k)
    plt.imshow(cv2.cvtColor(x[k], cv2.COLOR_BGR2RGB))
    plt.title(get_label(y[k]))
    plt.axis("off")

plt.suptitle("Sample Images from Dataset")
plt.show()

# %% [markdown]
# ### Splitting the Dataset into Training & Test Set

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 12)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 12)

print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_val.shape, y_val.shape)
print("Test set:", x_test.shape, y_test.shape)
# Out:
# Training set: (544, 32, 32) (544,)
# Validation set: (136, 32, 32) (136,)
# Test set: (170, 32, 32) (170,)

# %% [markdown]
# ### Building the Model

# %%
inputs = Input(shape = (32, 32, 1))

x = Flatten()(inputs)

x = Dense(128, activation = "relu")(x)
x = Dense(256, activation = "relu")(x)
x = Dense(512, activation = "relu")(x)
x = Dense(256, activation = "relu")(x)
x = Dense(128, activation = "relu")(x)

outputs = Dense(1, activation = "sigmoid")(x)

model = Model(inputs = inputs, outputs = outputs)

model.compile(optimizer = Adam(0.0001), loss = "binary_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# Model: "functional_31"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_15 (InputLayer)     │ (None, 32, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_15 (Flatten)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_90 (Dense)                │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_91 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_92 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_93 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_94 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 460,161 (1.76 MB)
#  Trainable params: 460,161 (1.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs = 25, validation_data = (x_val, y_val))
# Out:
# Epoch 1/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5211 - loss: 7.7044 - val_accuracy: 0.6029 - val_loss: 2.1285
# Epoch 2/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5727 - loss: 1.7153 - val_accuracy: 0.6618 - val_loss: 1.0483
# Epoch 3/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7165 - loss: 0.8384 - val_accuracy: 0.7721 - val_loss: 0.5693
# Epoch 4/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8011 - loss: 0.5713 - val_accuracy: 0.6250 - val_loss: 1.3110
# Epoch 5/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7279 - loss: 0.8802 - val_accuracy: 0.7868 - val_loss: 0.6131
# Epoch 6/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8132 - loss: 0.4988 - val_accuracy: 0.7941 - val_loss: 0.5197
# Epoch 7/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8145 - loss: 0.5298 - val_accuracy: 0.7574 - val_loss: 0.7425
# Epoch 8/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8505 - loss: 0.4870 - val_accuracy: 0.6250 - val_loss: 1.1753
# Epoch 9/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7810 - loss: 0.7028 - val_accuracy: 0.8162 - val_loss: 0.5102
# Epoch 10/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8399 - loss: 0.4273 - val_accuracy: 0.7868 - val_loss: 0.6314
# Epoch 11/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8200 - loss: 0.3771 - val_accuracy: 0.8235 - val_loss: 0.4752
# Epoch 12/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8634 - loss: 0.3325 - val_accuracy: 0.7941 - val_loss: 0.5325
# Epoch 13/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8323 - loss: 0.3646 - val_accuracy: 0.7721 - val_loss: 0.7515
# Epoch 14/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8650 - loss: 0.2982 - val_accuracy: 0.8456 - val_loss: 0.5304
# Epoch 15/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9073 - loss: 0.2347 - val_accuracy: 0.8382 - val_loss: 0.5069
# Epoch 16/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8667 - loss: 0.3279 - val_accuracy: 0.8015 - val_loss: 0.6697
# Epoch 17/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8429 - loss: 0.4499 - val_accuracy: 0.7647 - val_loss: 0.7995
# Epoch 18/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8817 - loss: 0.3059 - val_accuracy: 0.7941 - val_loss: 0.5547
# Epoch 19/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9296 - loss: 0.1796 - val_accuracy: 0.7500 - val_loss: 0.6359
# Epoch 20/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8812 - loss: 0.2509 - val_accuracy: 0.7721 - val_loss: 0.5712
# Epoch 21/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8880 - loss: 0.2739 - val_accuracy: 0.8015 - val_loss: 0.5166
# Epoch 22/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9325 - loss: 0.1903 - val_accuracy: 0.8309 - val_loss: 0.4908
# Epoch 23/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9271 - loss: 0.1813 - val_accuracy: 0.8309 - val_loss: 0.5221
# Epoch 24/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8754 - loss: 0.3018 - val_accuracy: 0.6912 - val_loss: 0.9401
# Epoch 25/25
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8517 - loss: 0.4052 - val_accuracy: 0.8603 - val_loss: 0.4536

# %% [markdown]
# ### Plotting The Accuracy & Loss Graph

# %%
plt.figure(figsize = (17, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label = "Accuracy")
plt.plot(history.history["val_accuracy"], label = "Validation Accuracy")
plt.title("Training & Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label = "Loss")
plt.plot(history.history["val_loss"], label = "Validation Loss")
plt.title("Training & Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluating the Model on Test Set

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f"Test Accuracy: {round(test_accuracy * 100, 2)}%")
print(f"Test Loss: {round(test_loss * 100, 2)}%")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8650 - loss: 0.3920
# Test Accuracy: 84.12%
# Test Loss: 44.39%
